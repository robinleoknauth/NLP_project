# %%
import pandas as pd
import numpy as np
import seaborn as sns

import pickle
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

from nltk.probability import FreqDist

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import NMF
from sklearn.decomposition import PCA

from sklearn.manifold import TSNE

from sklearn.pipeline import Pipeline

from gensim import corpora, models, similarities, matutils

import re
import string

from wordcloud import WordCloud, STOPWORDS

from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors



# call glove2word2vec script
# default way (through CLI): python -m gensim.scripts.glove2word2vec --input <glove_file> --output <w2v_file>
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
df_merged = pd.read_pickle("./data/df_merged_cleaned.pkl")

# %% [markdown]
# ### Tokenization

# %%
stop_words = set(stopwords.words('english'))

# %%
df_merged['tokenized_text'] = df_merged['text'].apply(word_tokenize)

# %% [markdown]
# ## Lemmatization

# %%
lemmatizer=WordNetLemmatizer()


df_merged['lemmatized_text'] = df_merged['tokenized_text'].apply(lambda x: [lemmatizer.lemmatize(y) for y in x])

# %%
vectorizer_tfidf = TfidfVectorizer(stop_words="english",
                        use_idf=True,
                        ngram_range=(1,1), 
                        min_df = 0.05,     
                        max_df = 0.35)

# %%
df_merged['lemma_text_string'] = df_merged['lemmatized_text'].apply(', '.join)

# %%
tfidf = vectorizer_tfidf.fit_transform(df_merged['lemma_text_string'])

# %%
number_topics = 20
lda = LatentDirichletAllocation(n_components = number_topics,random_state = 0)

topics = lda.fit_transform(tfidf)
top_n_words = 10
t_words, word_strengths = {}, {}
for t_id, t in enumerate(lda.components_):
    t_words[t_id] = [vectorizer_tfidf.get_feature_names()[i] for i in t.argsort()[:-top_n_words - 1:-1]]
    word_strengths[t_id] = t[t.argsort()[:-top_n_words - 1:-1]]
t_words
# Out:
# {0: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  1: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  2: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  3: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  4: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  5: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  6: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  7: ['woman',
#   'brain',
#   'city',
#   'kid',
#   'data',
#   'water',
#   'design',
#   'family',
#   'community',
#   'information'],
#  8: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  9: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  10: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  11: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  12: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  13: ['sorry',
#   'brother',
#   'play',
#   'okay',
#   'oh',
#   'song',
#   'funny',
#   'excited',
#   'boy',
#   'man'],
#  14: ['ca',
#   'welcome',
#   'chose',
#   'cause',
#   'tear',
#   'song',
#   'man',
#   'awesome',
#   'robot',
#   'pop'],
#  15: ['cell',
#   'planet',
#   'earth',
#   'dna',
#   'universe',
#   'cancer',
#   'ocean',
#   'gene',
#   'molecule',
#   'star'],
#  16: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  17: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  18: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain'],
#  19: ['man',
#   'tear',
#   'song',
#   'awesome',
#   'robot',
#   'capture',
#   'dance',
#   'cause',
#   'raise',
#   'rain']}

# %%
number_topics = 20
pca = PCA(n_components = number_topics,random_state = 0 )

topics = pca.fit_transform(np.array(pd.DataFrame(tfidf.toarray())))
top_n_words = 10
t_words, word_strengths = {}, {}
for t_id, t in enumerate(pca.components_):
    t_words[t_id] = [vectorizer_tfidf.get_feature_names()[i] for i in t.argsort()[:-top_n_words - 1:-1]]
    word_strengths[t_id] = t[t.argsort()[:-top_n_words - 1:-1]]
t_words
# Out:
# {0: ['woman',
#   'men',
#   'girl',
#   'family',
#   'mother',
#   'kid',
#   'man',
#   'young',
#   'boy',
#   'father'],
#  1: ['brain',
#   'cell',
#   'cancer',
#   'patient',
#   'woman',
#   'disease',
#   'body',
#   'drug',
#   'gene',
#   'doctor'],
#  2: ['cancer',
#   'cell',
#   'patient',
#   'disease',
#   'health',
#   'drug',
#   'government',
#   'africa',
#   'dollar',
#   'food'],
#  3: ['woman',
#   'water',
#   'ocean',
#   'planet',
#   'earth',
#   'animal',
#   'sea',
#   'men',
#   'specie',
#   'ice'],
#  4: ['city',
#   'building',
#   'design',
#   'cancer',
#   'cell',
#   'patient',
#   'architecture',
#   'community',
#   'car',
#   'neighborhood'],
#  5: ['brain',
#   'city',
#   'woman',
#   'men',
#   'building',
#   'space',
#   'image',
#   'region',
#   'pattern',
#   'architecture'],
#  6: ['woman',
#   'robot',
#   'data',
#   'men',
#   'computer',
#   'machine',
#   'cell',
#   'design',
#   'cancer',
#   'universe'],
#  7: ['robot',
#   'kid',
#   'student',
#   'food',
#   'brain',
#   'water',
#   'animal',
#   'machine',
#   'teacher',
#   'woman'],
#  8: ['robot',
#   'music',
#   'city',
#   'war',
#   'song',
#   'sound',
#   'democracy',
#   'play',
#   'political',
#   'china'],
#  9: ['cell',
#   'dna',
#   'gene',
#   'plant',
#   'specie',
#   'music',
#   'animal',
#   'forest',
#   'language',
#   'art'],
#  10: ['music',
#   'woman',
#   'car',
#   'sound',
#   'water',
#   'company',
#   'song',
#   'data',
#   'energy',
#   'play'],
#  11: ['data',
#   'ocean',
#   'animal',
#   'information',
#   'fish',
#   'sea',
#   'water',
#   'image',
#   'internet',
#   'web'],
#  12: ['music',
#   'data',
#   'africa',
#   'student',
#   'health',
#   'education',
#   'teacher',
#   'sound',
#   'patient',
#   'woman'],
#  13: ['design',
#   'patient',
#   'designer',
#   'art',
#   'africa',
#   'building',
#   'product',
#   'object',
#   'material',
#   'health'],
#  14: ['africa',
#   'cell',
#   'african',
#   'light',
#   'image',
#   'brain',
#   'india',
#   'aid',
#   'girl',
#   'student'],
#  15: ['africa',
#   'data',
#   'african',
#   'dna',
#   'music',
#   'machine',
#   'universe',
#   'family',
#   'car',
#   'plant'],
#  16: ['food',
#   'plant',
#   'data',
#   'book',
#   'art',
#   'image',
#   'language',
#   'painting',
#   'artist',
#   'africa'],
#  17: ['water',
#   'energy',
#   'plant',
#   'language',
#   'war',
#   'information',
#   'nuclear',
#   'building',
#   'material',
#   'data'],
#  18: ['cancer',
#   'book',
#   'machine',
#   'computer',
#   'music',
#   'robot',
#   'language',
#   'city',
#   'water',
#   'brain'],
#  19: ['ca',
#   'car',
#   'student',
#   'language',
#   'africa',
#   'machine',
#   'ocean',
#   'animal',
#   'english',
#   'teacher']}

# %%
number_topics = 20
nmf = NMF(n_components = number_topics,random_state = 0)

topics = nmf.fit_transform(tfidf)
top_n_words = 10
t_words, word_strengths = {}, {}
for t_id, t in enumerate(nmf.components_):
    t_words[t_id] = [vectorizer_tfidf.get_feature_names()[i] for i in t.argsort()[:-top_n_words - 1:-1]]
    word_strengths[t_id] = t[t.argsort()[:-top_n_words - 1:-1]]
t_words
# Out:
# {0: ['god',
#   'man',
#   'family',
#   'father',
#   'mother',
#   'oh',
#   'book',
#   'felt',
#   'night',
#   'yeah'],
#  1: ['woman',
#   'men',
#   'girl',
#   'sex',
#   'gender',
#   'female',
#   'boy',
#   'male',
#   'mother',
#   'violence'],
#  2: ['cell',
#   'dna',
#   'gene',
#   'cancer',
#   'molecule',
#   'body',
#   'drug',
#   'protein',
#   'organ',
#   'blood'],
#  3: ['company',
#   'business',
#   'dollar',
#   'money',
#   'market',
#   'economy',
#   'cost',
#   'product',
#   'value',
#   'economic'],
#  4: ['ocean',
#   'fish',
#   'sea',
#   'animal',
#   'ice',
#   'specie',
#   'island',
#   'boat',
#   'deep',
#   'surface'],
#  5: ['design',
#   'building',
#   'designer',
#   'architecture',
#   'material',
#   'project',
#   'architect',
#   'designed',
#   'space',
#   'structure'],
#  6: ['brain',
#   'behavior',
#   'memory',
#   'body',
#   'activity',
#   'pattern',
#   'signal',
#   'arm',
#   'study',
#   'mental'],
#  7: ['data',
#   'information',
#   'computer',
#   'machine',
#   'internet',
#   'web',
#   'phone',
#   'algorithm',
#   'digital',
#   'online'],
#  8: ['robot',
#   'machine',
#   'leg',
#   'video',
#   'body',
#   'intelligence',
#   'computer',
#   'animal',
#   'artificial',
#   'build'],
#  9: ['government',
#   'war',
#   'democracy',
#   'political',
#   'society',
#   'american',
#   'election',
#   'conflict',
#   'group',
#   'social'],
#  10: ['patient',
#   'cancer',
#   'disease',
#   'health',
#   'doctor',
#   'drug',
#   'medical',
#   'care',
#   'treatment',
#   'hospital'],
#  11: ['universe',
#   'planet',
#   'earth',
#   'star',
#   'space',
#   'light',
#   'sun',
#   'solar',
#   'science',
#   'billion'],
#  12: ['music',
#   'sound',
#   'play',
#   'song',
#   'hear',
#   'instrument',
#   'playing',
#   'video',
#   'piece',
#   'game'],
#  13: ['kid',
#   'teacher',
#   'student',
#   'education',
#   'learning',
#   'classroom',
#   'class',
#   'teach',
#   'teaching',
#   'learn'],
#  14: ['city',
#   'building',
#   'street',
#   'community',
#   'neighborhood',
#   'urban',
#   'space',
#   'map',
#   'york',
#   'park'],
#  15: ['africa',
#   'african',
#   'aid',
#   'continent',
#   'south',
#   'poverty',
#   'india',
#   'family',
#   'china',
#   'leader'],
#  16: ['plant',
#   'food',
#   'forest',
#   'specie',
#   'animal',
#   'tree',
#   'nature',
#   'eat',
#   'gene',
#   'farmer'],
#  17: ['water',
#   'energy',
#   'oil',
#   'climate',
#   'fuel',
#   'material',
#   'ice',
#   'river',
#   'waste',
#   'solar'],
#  18: ['art',
#   'image',
#   'artist',
#   'painting',
#   'book',
#   'film',
#   'museum',
#   'object',
#   'project',
#   'camera'],
#  19: ['car',
#   'ca',
#   'vehicle',
#   'mile',
#   'driver',
#   'driving',
#   'road',
#   'drive',
#   'traffic',
#   'yeah']}

# %%
pipe = Pipeline([
    ('tfidf', vectorizer_tfidf),
    ('nmf', nmf)
])

# %%
df_topics = pipe.transform(df_merged['lemma_text_string']) 
df_topics = pd.DataFrame(df_topics, columns=[str(t_words[i]) for i in range(0,number_topics)])
df_topics.head(50)
# Out:
#     ['god', 'man', 'family', 'father', 'mother', 'oh', 'book', 'felt', 'night', 'yeah']  \
# 0                                            0.043847
# 1                                            0.026450
# 2                                            0.044188
# 3                                            0.009847
# 4                                            0.000000
# 5                                            0.068339
# 6                                            0.124439
# 7                                            0.000000
# 8                                            0.046722
# 9                                            0.073558
# 10                                           0.000000
# 11                                           0.043791
# 12                                           0.030350
# 13                                           0.002319
# 14                                           0.016721
# 15                                           0.022765
# 16                                           0.018704
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.015256
# 20                                           0.000000
# 21                                           0.060327
# 22                                           0.076236
# 23                                           0.000000
# 24                                           0.027978
# 25                                           0.000000
# 26                                           0.006385
# 27                                           0.049477
# 28                                           0.036899
# 29                                           0.049291
# 30                                           0.030380
# 31                                           0.000761
# 32                                           0.031074
# 33                                           0.000720
# 34                                           0.003161
# 35                                           0.007073
# 36                                           0.000000
# 37                                           0.015802
# 38                                           0.048642
# 39                                           0.030891
# 40                                           0.019877
# 41                                           0.012326
# 42                                           0.022581
# 43                                           0.032078
# 44                                           0.000000
# 45                                           0.006886
# 46                                           0.048283
# 47                                           0.031490
# 48                                           0.029127
# 49                                           0.000000
#
#     ['woman', 'men', 'girl', 'sex', 'gender', 'female', 'boy', 'male', 'mother', 'violence']  \
# 0                                            0.041454
# 1                                            0.000000
# 2                                            0.000000
# 3                                            0.010055
# 4                                            0.009682
# 5                                            0.021258
# 6                                            0.054101
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.023472
# 11                                           0.049954
# 12                                           0.013334
# 13                                           0.000000
# 14                                           0.000000
# 15                                           0.000000
# 16                                           0.000000
# 17                                           0.017404
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.012154
# 23                                           0.182560
# 24                                           0.246369
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0.016786
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000000
# 32                                           0.000000
# 33                                           0.000000
# 34                                           0.058038
# 35                                           0.002877
# 36                                           0.028750
# 37                                           0.000000
# 38                                           0.000000
# 39                                           0.000000
# 40                                           0.002248
# 41                                           0.002479
# 42                                           0.006476
# 43                                           0.000000
# 44                                           0.000000
# 45                                           0.000000
# 46                                           0.019040
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.000000
#
#     ['cell', 'dna', 'gene', 'cancer', 'molecule', 'body', 'drug', 'protein', 'organ', 'blood']  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.010444
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.001942
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.003199
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.006784
# 14                                           0.018579
# 15                                           0.000000
# 16                                           0.000971
# 17                                           0.000000
# 18                                           0.009698
# 19                                           0.000000
# 20                                           0.007870
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.005086
# 25                                           0.002839
# 26                                           0.001759
# 27                                           0.001900
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.023280
# 31                                           0.138055
# 32                                           0.089674
# 33                                           0.014867
# 34                                           0.000000
# 35                                           0.000000
# 36                                           0.004682
# 37                                           0.008152
# 38                                           0.000000
# 39                                           0.000000
# 40                                           0.000000
# 41                                           0.000000
# 42                                           0.021815
# 43                                           0.000695
# 44                                           0.100733
# 45                                           0.036894
# 46                                           0.000000
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.007005
#
#     ['company', 'business', 'dollar', 'money', 'market', 'economy', 'cost', 'product', 'value', 'economic']  \
# 0                                            0.005237
# 1                                            0.062064
# 2                                            0.050816
# 3                                            0.048190
# 4                                            0.034406
# 5                                            0.047076
# 6                                            0.000000
# 7                                            0.017774
# 8                                            0.000000
# 9                                            0.045047
# 10                                           0.013275
# 11                                           0.000000
# 12                                           0.013964
# 13                                           0.000000
# 14                                           0.053441
# 15                                           0.000000
# 16                                           0.000307
# 17                                           0.057635
# 18                                           0.014974
# 19                                           0.026853
# 20                                           0.025052
# 21                                           0.059940
# 22                                           0.036516
# 23                                           0.018418
# 24                                           0.000000
# 25                                           0.016474
# 26                                           0.000000
# 27                                           0.089751
# 28                                           0.040395
# 29                                           0.020396
# 30                                           0.069837
# 31                                           0.000000
# 32                                           0.024833
# 33                                           0.177775
# 34                                           0.144837
# 35                                           0.113030
# 36                                           0.111999
# 37                                           0.048249
# 38                                           0.000000
# 39                                           0.003143
# 40                                           0.046748
# 41                                           0.004637
# 42                                           0.004080
# 43                                           0.004437
# 44                                           0.075314
# 45                                           0.008236
# 46                                           0.000000
# 47                                           0.038619
# 48                                           0.002774
# 49                                           0.038127
#
#     ['ocean', 'fish', 'sea', 'animal', 'ice', 'specie', 'island', 'boat', 'deep', 'surface']  \
# 0                                            0.000000
# 1                                            0.005586
# 2                                            0.000000
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000000
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.002000
# 12                                           0.007321
# 13                                           0.000000
# 14                                           0.001753
# 15                                           0.000450
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.003918
# 24                                           0.019338
# 25                                           0.000000
# 26                                           0.010212
# 27                                           0.000287
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.005057
# 31                                           0.000000
# 32                                           0.000000
# 33                                           0.000000
# 34                                           0.004718
# 35                                           0.002467
# 36                                           0.000000
# 37                                           0.000000
# 38                                           0.106608
# 39                                           0.001135
# 40                                           0.005456
# 41                                           0.000891
# 42                                           0.002848
# 43                                           0.001200
# 44                                           0.000000
# 45                                           0.012054
# 46                                           0.018844
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.000000
#
#     ['design', 'building', 'designer', 'architecture', 'material', 'project', 'architect', 'designed', 'space', 'structure']  \
# 0                                            0.000000
# 1                                            0.023594
# 2                                            0.061260
# 3                                            0.015242
# 4                                            0.000000
# 5                                            0.002904
# 6                                            0.000000
# 7                                            0.147667
# 8                                            0.064384
# 9                                            0.000000
# 10                                           0.209303
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.020112
# 14                                           0.024850
# 15                                           0.102056
# 16                                           0.015745
# 17                                           0.026176
# 18                                           0.157982
# 19                                           0.011766
# 20                                           0.045536
# 21                                           0.007159
# 22                                           0.000000
# 23                                           0.000149
# 24                                           0.001541
# 25                                           0.011149
# 26                                           0.013153
# 27                                           0.000000
# 28                                           0.001952
# 29                                           0.001625
# 30                                           0.003956
# 31                                           0.000000
# 32                                           0.002813
# 33                                           0.000000
# 34                                           0.005295
# 35                                           0.000000
# 36                                           0.047455
# 37                                           0.038124
# 38                                           0.000000
# 39                                           0.000000
# 40                                           0.023442
# 41                                           0.017220
# 42                                           0.005884
# 43                                           0.022121
# 44                                           0.057397
# 45                                           0.000583
# 46                                           0.000000
# 47                                           0.000901
# 48                                           0.000000
# 49                                           0.000000
#
#     ['brain', 'behavior', 'memory', 'body', 'activity', 'pattern', 'signal', 'arm', 'study', 'mental']  \
# 0                                            0.019192
# 1                                            0.000000
# 2                                            0.000000
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.024677
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.037011
# 9                                            0.000326
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.002055
# 13                                           0.006653
# 14                                           0.000000
# 15                                           0.000058
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.177844
# 24                                           0.000151
# 25                                           0.016619
# 26                                           0.093554
# 27                                           0.003810
# 28                                           0.000000
# 29                                           0.047450
# 30                                           0.000694
# 31                                           0.021656
# 32                                           0.035474
# 33                                           0.000000
# 34                                           0.000000
# 35                                           0.000000
# 36                                           0.000000
# 37                                           0.000000
# 38                                           0.000000
# 39                                           0.008671
# 40                                           0.000000
# 41                                           0.105782
# 42                                           0.018839
# 43                                           0.020510
# 44                                           0.089521
# 45                                           0.012900
# 46                                           0.000000
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.000316
#
#     ['data', 'information', 'computer', 'machine', 'internet', 'web', 'phone', 'algorithm', 'digital', 'online']  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.055219
# 3                                            0.000000
# 4                                            0.108806
# 5                                            0.017975
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.018032
# 13                                           0.090861
# 14                                           0.031158
# 15                                           0.000000
# 16                                           0.000876
# 17                                           0.001046
# 18                                           0.000000
# 19                                           0.057050
# 20                                           0.030723
# 21                                           0.034640
# 22                                           0.026317
# 23                                           0.004639
# 24                                           0.000000
# 25                                           0.006431
# 26                                           0.007924
# 27                                           0.007696
# 28                                           0.043798
# 29                                           0.024837
# 30                                           0.004436
# 31                                           0.000000
# 32                                           0.000251
# 33                                           0.011153
# 34                                           0.000000
# 35                                           0.020833
# 36                                           0.000000
# 37                                           0.012897
# 38                                           0.013866
# 39                                           0.018912
# 40                                           0.010443
# 41                                           0.028938
# 42                                           0.010743
# 43                                           0.054805
# 44                                           0.063746
# 45                                           0.026530
# 46                                           0.017486
# 47                                           0.001670
# 48                                           0.057124
# 49                                           0.000000
#
#     ['robot', 'machine', 'leg', 'video', 'body', 'intelligence', 'computer', 'animal', 'artificial', 'build']  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.000235
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000798
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.011247
# 14                                           0.002856
# 15                                           0.000000
# 16                                           0.000000
# 17                                           0.001354
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000782
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.006010
# 27                                           0.000000
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000374
# 32                                           0.000027
# 33                                           0.000000
# 34                                           0.002988
# 35                                           0.000000
# 36                                           0.000000
# 37                                           0.014736
# 38                                           0.000000
# 39                                           0.000000
# 40                                           0.004341
# 41                                           0.000000
# 42                                           0.001785
# ...
# 42                                           0.022708
# 43                                           0.011345
# 44                                           0.025425
# 45                                           0.090280
# 46                                           0.021822
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.060386
#
#     ['water', 'energy', 'oil', 'climate', 'fuel', 'material', 'ice', 'river', 'waste', 'solar']  \
# 0                                            0.000088
# 1                                            0.051441
# 2                                            0.000000
# 3                                            0.051259
# 4                                            0.000000
# 5                                            0.000000
# 6                                            0.022187
# 7                                            0.002065
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.007373
# 11                                           0.000000
# 12                                           0.011350
# 13                                           0.007386
# 14                                           0.013597
# 15                                           0.000000
# 16                                           0.000000
# 17                                           0.173576
# 18                                           0.084352
# 19                                           0.000000
# 20                                           0.018289
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.015887
# 25                                           0.000000
# 26                                           0.005540
# 27                                           0.000000
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000000
# 32                                           0.000000
# 33                                           0.000000
# 34                                           0.024300
# 35                                           0.000000
# 36                                           0.000000
# 37                                           0.000000
# 38                                           0.089042
# 39                                           0.000000
# 40                                           0.049365
# 41                                           0.006037
# 42                                           0.000000
# 43                                           0.000000
# 44                                           0.014463
# 45                                           0.000000
# 46                                           0.000000
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.000000
#
#     ['art', 'image', 'artist', 'painting', 'book', 'film', 'museum', 'object', 'project', 'camera']  \
# 0                                            0.048016
# 1                                            0.006068
# 2                                            0.004695
# 3                                            0.001957
# 4                                            0.000000
# 5                                            0.019245
# 6                                            0.000000
# 7                                            0.102495
# 8                                            0.010445
# 9                                            0.027345
# 10                                           0.000000
# 11                                           0.084846
# 12                                           0.020030
# 13                                           0.038547
# 14                                           0.031194
# 15                                           0.000000
# 16                                           0.071059
# 17                                           0.000000
# 18                                           0.068137
# 19                                           0.031775
# 20                                           0.058734
# 21                                           0.028420
# 22                                           0.064765
# 23                                           0.001117
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.004442
# 27                                           0.007675
# 28                                           0.005927
# 29                                           0.008902
# 30                                           0.000000
# 31                                           0.000000
# 32                                           0.000000
# 33                                           0.000000
# 34                                           0.000000
# 35                                           0.017270
# 36                                           0.000000
# 37                                           0.003990
# 38                                           0.001045
# 39                                           0.004115
# 40                                           0.066654
# 41                                           0.000423
# 42                                           0.012756
# 43                                           0.033006
# 44                                           0.000000
# 45                                           0.002591
# 46                                           0.033314
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.006286
#
#     ['car', 'ca', 'vehicle', 'mile', 'driver', 'driving', 'road', 'drive', 'traffic', 'yeah']
# 0                                            0.000000
# 1                                            0.084008
# 2                                            0.025782
# 3                                            0.016891
# 4                                            0.000000
# 5                                            0.002724
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000281
# 11                                           0.002365
# 12                                           0.013998
# 13                                           0.008650
# 14                                           0.042628
# 15                                           0.003750
# 16                                           0.008092
# 17                                           0.044326
# 18                                           0.144355
# 19                                           0.000358
# 20                                           0.000000
# 21                                           0.013663
# 22                                           0.000000
# 23                                           0.040192
# 24                                           0.000317
# 25                                           0.000000
# 26                                           0.029766
# 27                                           0.020888
# 28                                           0.006076
# 29                                           0.005985
# 30                                           0.016390
# 31                                           0.000000
# 32                                           0.020628
# 33                                           0.036334
# 34                                           0.005269
# 35                                           0.000000
# 36                                           0.028316
# 37                                           0.049306
# 38                                           0.020343
# 39                                           0.000000
# 40                                           0.036184
# 41                                           0.019356
# 42                                           0.014551
# 43                                           0.000000
# 44                                           0.006848
# 45                                           0.026261
# 46                                           0.016454
# 47                                           0.009131
# 48                                           0.002804
# 49                                           0.000237

# %%
best_topics = df_topics.idxmax(axis=1)
best_topics
# Out:
# 0       ['kid', 'teacher', 'student', 'education', 'le...
# 1       ['car', 'ca', 'vehicle', 'mile', 'driver', 'dr...
# 2       ['design', 'building', 'designer', 'architectu...
# 3       ['city', 'building', 'street', 'community', 'n...
# 4       ['africa', 'african', 'aid', 'continent', 'sou...
# 5       ['god', 'man', 'family', 'father', 'mother', '...
# 6       ['god', 'man', 'family', 'father', 'mother', '...
# 7       ['design', 'building', 'designer', 'architectu...
# 8       ['design', 'building', 'designer', 'architectu...
# 9       ['god', 'man', 'family', 'father', 'mother', '...
# 10      ['design', 'building', 'designer', 'architectu...
# 11      ['art', 'image', 'artist', 'painting', 'book',...
# 12      ['patient', 'cancer', 'disease', 'health', 'do...
# 13      ['data', 'information', 'computer', 'machine',...
# 14      ['kid', 'teacher', 'student', 'education', 'le...
# 15      ['design', 'building', 'designer', 'architectu...
# 16      ['music', 'sound', 'play', 'song', 'hear', 'in...
# 17      ['water', 'energy', 'oil', 'climate', 'fuel', ...
# 18      ['design', 'building', 'designer', 'architectu...
# 19      ['data', 'information', 'computer', 'machine',...
# 20      ['music', 'sound', 'play', 'song', 'hear', 'in...
# 21      ['god', 'man', 'family', 'father', 'mother', '...
# 22      ['god', 'man', 'family', 'father', 'mother', '...
# 23      ['woman', 'men', 'girl', 'sex', 'gender', 'fem...
# 24      ['woman', 'men', 'girl', 'sex', 'gender', 'fem...
# 25      ['universe', 'planet', 'earth', 'star', 'space...
# 26      ['universe', 'planet', 'earth', 'star', 'space...
# 27      ['company', 'business', 'dollar', 'money', 'ma...
# 28      ['data', 'information', 'computer', 'machine',...
# 29      ['god', 'man', 'family', 'father', 'mother', '...
#                               ...
# 2437    ['brain', 'behavior', 'memory', 'body', 'activ...
# 2438    ['cell', 'dna', 'gene', 'cancer', 'molecule', ...
# 2439    ['art', 'image', 'artist', 'painting', 'book',...
# 2440    ['company', 'business', 'dollar', 'money', 'ma...
# 2441    ['africa', 'african', 'aid', 'continent', 'sou...
# 2442    ['kid', 'teacher', 'student', 'education', 'le...
# 2443    ['robot', 'machine', 'leg', 'video', 'body', '...
# 2444    ['government', 'war', 'democracy', 'political'...
# 2445    ['art', 'image', 'artist', 'painting', 'book',...
# 2446    ['government', 'war', 'democracy', 'political'...
# 2447    ['water', 'energy', 'oil', 'climate', 'fuel', ...
# 2448    ['government', 'war', 'democracy', 'political'...
# 2449    ['company', 'business', 'dollar', 'money', 'ma...
# 2450    ['universe', 'planet', 'earth', 'star', 'space...
# 2451    ['universe', 'planet', 'earth', 'star', 'space...
# 2452    ['city', 'building', 'street', 'community', 'n...
# 2453    ['government', 'war', 'democracy', 'political'...
# 2454    ['god', 'man', 'family', 'father', 'mother', '...
# 2455    ['company', 'business', 'dollar', 'money', 'ma...
# 2456    ['africa', 'african', 'aid', 'continent', 'sou...
# 2457    ['company', 'business', 'dollar', 'money', 'ma...
# 2458    ['universe', 'planet', 'earth', 'star', 'space...
# 2459    ['woman', 'men', 'girl', 'sex', 'gender', 'fem...
# 2460    ['data', 'information', 'computer', 'machine',...
# 2461    ['africa', 'african', 'aid', 'continent', 'sou...
# 2462    ['government', 'war', 'democracy', 'political'...
# 2463    ['water', 'energy', 'oil', 'climate', 'fuel', ...
# 2464    ['robot', 'machine', 'leg', 'video', 'body', '...
# 2465    ['government', 'war', 'democracy', 'political'...
# 2466    ['city', 'building', 'street', 'community', 'n...
# Length: 2467, dtype: object

# %%
best_topics = pd.DataFrame(best_topics)

# %%
best_topics.head(3)
# Out:
#                                                    0
# 0  ['kid', 'teacher', 'student', 'education', 'le...
# 1  ['car', 'ca', 'vehicle', 'mile', 'driver', 'dr...
# 2  ['design', 'building', 'designer', 'architectu...

# %%
# best_topics[0] = best_topics[0].map(punc_lower).map(alphanumeric)

# %%
# best_topics[0] = best_topics[0].apply(lambda x: x.split(' '))

# %%
# best_topics.head(5)

# %%
# best_topics[0] = best_topics[0].apply(lambda x: [s.strip() for s in x])

# %%
# model[best_topics[0][0]]

# %%
l = list( range(0, 2467) )

# %%
hello = list()
for i in l:
    hello.extend(np.mean(model[best_topics[0][i]], axis=0) )
    
hello = np.array(hello)
hello = hello.reshape((2467, 300))

# %%
hello= pd.DataFrame(hello)

# %%
hello.iloc[0].ravel()

# %%
model.similar_by_vector(hello.iloc[0].ravel())

# %%
model.vectors

# %%
df_topics_token = pipe.transform(df_merged['tokenized_text']) 
df_topics_token = pd.DataFrame(df_topics_token, columns=[str(t_words[i]) for i in range(0,10)])
df_topics_token.head()
